# %% [markdown]
# У завданнях 1-4. Вам наданий простий код на Python, який не відповідає вказівкам PEP8. Ваше завдання — відредагувати код так, аби він відповідав PEP8. Напишіть після редагуванню коду, дотримання яких правил з pep8 ви досягли в відредагованій версії. Можна просто зазначити правило по суті, без конкретного номеру. Але якщо зазначите номер - взагалі супер. Також можна зазанчити використані правила коментарями по коду.
#
# Відредагований код має виконувати весь той самий функціонал, але бути написаний відповідно до вимог до гарного коду на Python! Не забудьте запустити відредагований код, він має бути робочим.

# %% [markdown]
# Завдання 1.

# %%
def greet(name):print(f"Hello, {name}")
def add(n1,n2):return n1+n2

x = 5;y = 3
display(greet("John"),add(x,y))
# Out:
# Hello, John
# None
# 8

# %%
def greet(name):
    print(f"Hello, {name}")
#Whitespace in Expressions and Statements (Rule: E231) says Compound statements (multiple statements on the same line) are generally discouraged:
#so I moved print to the next line

def add(n1, n2):
    return n1 + n2
#Whitespace in Expressions and Statements (Rule: E231) says Compound statements (multiple statements on the same line) are generally discouraged:
#so I moved return to the next line

#Whitespace Expressions and Statements (Rule: E231) says that there should be a space after the comma and before the next argument
#so I put a space after the comma

#Whitespace Around Operators (Rule: E701) says Always surround these binary operators(includes +) with a single space on either side
#so I put spaces around +

x = 5
y = 3
#Whitespace in Expressions and Statements (Rule: E231) says Compound statements (multiple statements on the same line) are generally discouraged:
#so I removed ';'  as semicolons are not required in Python and moved y = 3 to the next line

display(greet("John"), add(x, y))

#Whitespace Expressions and Statements (Rule: E231) says that there should be a space after the comma and before the next argument
#so I put a space after each comma

#Blank Lines rule says Surround top-level function and class definitions with two blank lines),
# so I also put Blank Lines between lines and functions.
# Out:
# Hello, John
# None
# 8

# %% [markdown]
# Завдання 2.

# %%
from math import *
def calcArea(r):return pi*r**2
def calcCircumference(r):return 2*pi*r

radius=5
print("Area:",calcArea(radius),"Circumference:",calcCircumference(radius))
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %%
from math import pi

def calc_area(r):
    return pi * r ** 2

def calc_circumference(r):
    return 2 * pi * r

radius = 5

print("Area:", calc_area(radius), "Circumference:", calc_circumference(radius))

#Imports (Rule: E402) says You should import only what you need instead of using a wildcard (*) import. 
#so I only import pi constant from the math module

#Function Names (Rule: N802) says Function names should be in lowercase with words separated by underscores, 
#so I renamed functions

#Whitespace in Expressions and Statements (Rule: E231) says Compound statements (multiple statements on the same line) are generally discouraged:
#so I moved return to the next line

#Whitespace Expressions and Statements (Rule: E231) says that there should be a space after the comma and before the next argument
#so I put a space after each comma

#Whitespace Around Operators (Rule: E701) (or Binary Operators (Rule: E226)) says Always surround these binary operators(includes =) with a single space on either side
#so I put spaces around =, ** and *

#Blank Lines rule says Surround top-level function and class definitions with two blank lines),
# so I also put Blank Lines between lines and functions.
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %% [markdown]
# Завдання 3.

# %%
class animal: pass
class dog(animal): 
    def __init__(self,name):
        self.name=name
        self.type='Dog'

# %%
class Animal: 
    pass

class Dog(animal): 
    def __init__(self, name):
        self.name = name
        self.type = 'Dog'
        
#Class Names (Rule: N801) says Class names should be in "CamelCase" with the first letter capitalized.
#so I renamed classes
        
#Whitespace Expressions and Statements (Rule: E231) says that there should be a space after the comma and before the next argument
#so I put a space after each comma

#Whitespace Around Operators (Rule: E701) (or Binary Operators (Rule: E226)) says Always surround these binary operators(includes =) with a single space on either side
#so I put spaces around =
        
#Blank Lines rule says Surround top-level function and class definitions with two blank lines),
# so I also put Blank Lines between lines and functions.

# %% [markdown]
# Завдання 4.

# %%
list=[1,2,3,4,5]
for i in range(len(list)):print(list[i])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
list = [1, 2, 3, 4, 5]

for i in list:
    print(i)
    
#I utilized list properties that allow us to iterate through the list. It`s not in pep8, but a general convention.
    
#Whitespace Expressions and Statements (Rule: E231) says that there should be a space after the comma and before the next argument
#so I put a space after each comma

#Whitespace Around Operators (Rule: E701) (or Binary Operators (Rule: E226)) says Always surround these binary operators(includes =) with a single space on either side
#so I put spaces around =
        
#Blank Lines rule says Surround top-level function and class definitions with two blank lines),
# so I also put Blank Lines between lines and functions.
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 5.У вас є DataFrame df, що представляє результати тестів студентів з математики, англійської мови та історії. Поточний код обчислює середній бал для кожного студента шляхом ітерації за рядками DataFrame за допомогою iterrows().
#
# Ваше завдання полягає в тому, щоб змінити код так, аби уникнути використання iterrows() і замість цього застосувати більш ефективне та читабельне рішення відповідно до правил, озвучених у лекції. Рефакторинг треба зробити лише частині, де рахуються середні, імпорт і визначення датафрейму лишаємо без змін.

# %%
import pandas as pd

df = pd.DataFrame({
    'student': ['Alice', 'Bob', 'Charlie', 'David'],
    'math_score': [89, 94, 77, 85],
    'english_score': [92, 88, 79, 85],
    'history_score': [84, 92, 81, 89]
})

# %%
averages = []
for _, row in df.iterrows():
    averages.append((row['math_score'] + row['english_score'] + row['history_score']) / 3)

df['average_score'] = averages

# %%
df['average_score_2'] = df.mean(axis = 1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18476\1916888850.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['average_score_2'] = df.mean(axis = 1)

# %%
averages, df
# Out:
# ([88.33333333333333, 91.33333333333333, 79.0, 86.33333333333333],
#     student  math_score  english_score  history_score  average_score  \
#  0    Alice          89             92             84      88.333333
#  1      Bob          94             88             92      91.333333
#  2  Charlie          77             79             81      79.000000
#  3    David          85             85             89      86.333333
#
#     average_score_2
#  0        88.333333
#  1        91.333333
#  2        79.000000
#  3        86.333333  )

# %% [markdown]
# 6.У Вас є великий DataFrame df, що представляє транзакції продажу в магазині. Цей DataFrame містить понад 1 мільйон рядків і кілька стовпців, зокрема «product_name», «product_category», «product_price» і «transaction_date».
#
# І «product_name», і «product_category» є рядками, що представляють численні, але обмежені унікальні назви продуктів і категорії відповідно.
#
# Напишіть код для ефективного перетворення стовпців «product_name» і «product_category» на категорійний тип для ефективного використання пам’яті.
# Спробуйте вирішити це завдання, мінімізуючи використання пам'яті та зберігаючи читабельність коду. Крім того, виміряйте використання пам’яті до та після перетворення, щоб продемонструвати підвищення ефективності.
#
# Порівняйте кількість памʼяті, яку займає наданий набір даних і новий, створений Вами. В лекції був приклад. В скільки разів менше памʼяті займає новий датафрейм?

# %%
import pandas as pd
import numpy as np

np.random.seed(0)

products = ['apple', 'banana', 'cherry', 'dates', 'elderberry']
categories = ['fruit', 'fruit', 'fruit', 'fruit', 'fruit']

N_ROWS = 10**6
df = pd.DataFrame({
    'product_name': np.random.choice(products, N_ROWS),
    'product_category': np.random.choice(categories, N_ROWS),
    'product_price': np.random.uniform(1, 10, N_ROWS),
    'transaction_date': pd.date_range(start='1/1/2000', periods=N_ROWS, freq='h')
})

# %%
df.head(), df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   product_name      1000000 non-null  object
#  1   product_category  1000000 non-null  object
#  2   product_price     1000000 non-null  float64
#  3   transaction_date  1000000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 30.5+ MB
# (  product_name product_category  product_price    transaction_date
#  0   elderberry            fruit       4.696674 2000-01-01 00:00:00
#  1        apple            fruit       7.176635 2000-01-01 01:00:00
#  2        dates            fruit       2.507932 2000-01-01 02:00:00
#  3        dates            fruit       2.079303 2000-01-01 03:00:00
#  4        dates            fruit       9.482386 2000-01-01 04:00:00,
#  None)

# %%
df.memory_usage(index=False).sum()
# Out:
# 32000000

# %%
for col in df[['product_name', 'product_category']].columns:
    df[col] =  pd.Categorical(df[col])

# %%
df.memory_usage(index=False).sum()
# Out:
# 18000328

# %%
print(f"Маємо зниження витрат памʼяті на {round((1-18000328/32000000)*100,2)}% !")
# Out:
# Маємо зниження витрат памʼяті на 43.75% !

# %% [markdown]
# 7.В цьому завданні кілька пунктів. Треба виконати усі послідовно.
#     7.1. Завантажте дані у pandas dataframe з файла `ecommerce_data.csv`. Обовʼязково при завантаженні вкажіть параметр `encoding = 'ISO-8859-1'`, без нього буде помилка.
#     7.2. Заповніть пропущені значення в колонці CustomerID на -1 та перетворіть тип цієї колонки на str, адже зараз вона типу float, а це не правильний тип даних для ідентифікатора клієнта.
#     7.3. З допомогою бібліотеки sweetviz побудуйте html звіт, який порівнює дані для країни "Germany" і країни "France". У Вас можуть виникнути багато попереджень (Warning), їх рекомендую вимкнути наступним шматком коду
#
#
#     import warnings
#
#     with warnings.catch_warnings(record=True):
#         # your code
#
#
#    7.4.Напишіть 5 відмінностей для двох зазначених країн на основі побудованого звіту, без виконання додаткового аналізу іншими інструментами.

# %%
ecom_df = pd.read_csv('ecommerce_data.csv', encoding = 'ISO-8859-1')

# %%
ecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
ecom_df_no_na = ecom_df
ecom_df_no_na.CustomerID = ecom_df.CustomerID.fillna(-1).astype('str')
ecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   541909 non-null  object
#  7   Country      541909 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 33.1+ MB

# %%
#ecom_df[ecom_df.CustomerID.fillna(-1).isna()].count()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
! pip install sweetviz
# Out:
# ...
#      ---------------------------------------- 15.1/15.1 MB 2.0 MB/s eta 0:00:00
# ...

# %%
import sweetviz as sv
import warnings

with warnings.catch_warnings(record=True):
   # report = sv.analyze(ecom_df_no_na)
   # report.show_html('sweet_ecom_df_no_na.html')
    compare_report = sv.compare(
        ecom_df_no_na[ecom_df_no_na.Country == 'Germany'], 
        ecom_df_no_na[ecom_df_no_na.Country == 'France'])
    compare_report.show_html('sweet_ecom_df_no_na_compare_report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report sweet_ecom_df_no_na_compare_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# 1. Одинична ціна у Франції має одне викидне значення (4161) згідно з таблицею "Largest values", що спричиняє зростання більшості параметрів варіації. Проте, якщо виключити це значення, розподіли одиничних цін між різними країнами практично не відрізняються, як показано в таблиці "Квантилів". Варто зауважити, що за винятком 4161, майже всі найвищі одиничні ціни (від 21 до 600) спостерігаються в Німеччині. Ці дані свідчать про те, що дорогі товари можуть бути продані переважно в Німеччині.
#
# 2. Кількості понад 200 спостерігаються виключно у Франції.
#
# 3. 95-й перцентиль кількості становить 36 у Франції та 32 в Німеччині. Це вказує на те, що на ринку Франції, можливо, існує підгрупа споживачів, які більш нахильні до придбання більших кількостей порівняно з ринком Німеччини.
#
# 4. POSTAGE: 383 (Germany), 311 (France). "POSTAGE" має значну різницю в кількостях, яка може бути обумовлена логістичними причинами, вартістю доставки або відмінностями у звичках онлайн-шопінгу між двома країнами.
#
# 5. Деякі відмінності в продуктах
# RED TOADSTOOL LED NIGHT LIGHT:
# Germany: 47, France: 72
# PLASTERS IN TIN SPACEBOY:
# Germany: 51, France: 55
# PLASTERS IN TIN CIRCUS PARADE:
# Germany: 57, France: 68
# PLASTERS IN TIN WOODLAND ANIMALS:
# Germany: 67, France: 68
# Товари, такі як LED нічні лампи та пластири з тематичним малюнком, мають різні кількості в двох країнах. Це може вказувати на різні уподобання стосовно декоративних чи ностальгічних речей і свідчити про те, що певна естетика та почуття відіграють більшу роль на одному ринку, ніж на іншому. Це також може відображати сильніший маркетинг товарів для домашнього декору серед французьких споживачів.
# Я врахувала незначні різниці в кількості товарів, через те, що кількість клієнтів з Німеччини є більшою. Це означає, що коли кількість є вищою в Франції, відсоткова різниця виглядає більшою, ніж фактична різниця в кількості.

# %% [markdown]
# 8.З допомогою ChatGPT виявіть, чи є та які помилки в наступному коді.
# Попросіть після цього переписати код із дотриманням PEP8. Проаналізуйте результат. Чи справді ChatGPT виправив всі стилістичні помилки? Якщо ні, напишіть йому ще кілька запитів, аби код відповідав вимогам PEP8.
# Вставте фінальну версію коду з чату у ноутбук та запустіть на заданому списку. Має вертатись 50.
# Напишіть, які промпти (інструкції) при зверненні до ChatGPT ви застосували та додайте скріншот(-и) з промптами та відповідями чата.
# Якщо зробили висновки при виконанні цього завдання, то діліться також :)
#
# **ЯК ВСТАВИТИ СКРІНШОТ в Jupyter Notebook** :
# 1. Створіть нову Markdown клітинку
# 2. В новоствореній клітинці обираєте в меню Jupyter Notebook Edit -> Insert Image
# 3. Обираєте картинку
# 4. В клітинці має зʼявитись текст, який містить картинку. Запустіть клітинку.
#
# Або можна просто перетягнути картинку в Markdown клітинку.

# %%
def CalculateVariance(nl):
    sum_list = 0
    for n in nl:
        sum_list = sum_list + n
    mean = sum_list / len(nl)
    sum_squares = 0
    for n in nl:
        sum_squares = sum_squares + n**2
    mean_squares = sum_squares / len(nl)
    return mean_squares

# %%
input_list = [75, 80, 85, 90, 95]

# %%
CalculateVariance(input_list)
# Out:
# 7275.0

# %%
#pep8 aligned version
def calculate_variance(nl):
    sum_list = 0
    for n in nl:
        sum_list += n
    mean = sum_list / len(nl)
    
    sum_squares = 0
    for n in nl:
        sum_squares += n ** 2
    mean_squares = sum_squares / len(nl)
    
    return mean_squares

# %%
calculate_variance(input_list)
# Out:
# 7275.0

# %%
#optimazed and pep8 aligned version
def calculate_variance1(nl):
    sum_list = 0
    sum_squares = 0

    for n in nl:
        sum_list += n
        sum_squares += n ** 2

    mean = sum_list / len(nl)
    mean_squares = sum_squares / len(nl)

    return mean_squares

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
